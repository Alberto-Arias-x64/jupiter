# %%
import numpy as np 
import matplotlib.pyplot as plt

orange_light = '#FF9A13'
blue_light = '#1190FF'

# %%
def graficar_vectores(vecs,cols,alpha=1):

    plt.axvline(x = 0, color = "grey", zorder = 0)
    plt.axhline(y = 0, color = "grey", zorder = 0)

    for i in range(len(vecs)):
        x = np.concatenate([[0,0],vecs[i]])
        plt.quiver(
            [x[0]],
            [x[1]],
            [x[2]],
            [x[3]],
            angles = 'xy', scale_units = 'xy',
            scale = 1, alpha = alpha,
            color = cols[i]
        )

# %%
A = np.array([[-1,3],[2,-2]])
print (A)
# Out:
# [[-1  3]
#  [ 2 -2]]

# %%
vector = np.array([[2],[1]])
print (vector.flatten())
# Out:
# [2 1]

# %%
graficar_vectores([vector.flatten()],cols='blue')

plt.xlim(-5,5)
plt.ylim(-5,5)
# Out:
# (-5.0, 5.0)

# %%
vector_transformado = A.dot(vector)
print(vector_transformado.flatten())
# Out:
# [1 2]

# %%
graficar_vectores([vector.flatten(),vector_transformado.flatten()],cols=['blue','orange'])
plt.xlim(-4,4)
plt.ylim(-4,4)
# Out:
# (-4.0, 4.0)

# %%
X = np.array([[3,2],[4,1]])
v = np.array([[1],[1]])
u = X.dot(v)
graficar_vectores([u.flatten(),v.flatten()],cols=[orange_light,blue_light])
plt.xlim(-1,6)
plt.ylim(-1,6)
# Out:
# (-1.0, 6.0)

# %%
def graficarMatriz(matriz, vectorCol=['red', 'blue']):
    
    #círculo unitario
    x = np.linspace(-1, 1, 100000)
    y = np.sqrt(1 - (x**2))
    
    #Transformamos x e y en una matriz de vectores x, y
    vector_x_y = np.array([x, y])
    
    # círculo unitario transformado
    prod_punto = matriz.dot(vector_x_y)
    
    #vectores
    u1 = [matriz[0, 0], matriz[1, 0]]
    v1 = [matriz[0, 1], matriz[1, 1]]
    
    graficar_vectores([u1, v1], cols=[vectorCol[0], vectorCol[1]])
    
    plt.plot(prod_punto[0], prod_punto[1], 'orange', alpha = 0.7)
    plt.plot(-prod_punto[0], -prod_punto[1], 'green', alpha = 0.7)

# %%
a = np.array([[3,7],[5,2]])
print(a)
graficarMatriz(np.eye(2))
plt.xlim(-1.5,1.5)
plt.ylim(-1.5,1.5)
# Out:
# [[3 7]
#  [5 2]]
# (-1.5, 1.5)

# %%
a = np.array([[3,7],[5,2]])
print(a)
graficarMatriz(a)
plt.xlim(-8,8)
plt.ylim(-8,8)
# Out:
# [[3 7]
#  [5 2]]
# (-8.0, 8.0)

# %%
u,d,v = np.linalg.svd(a)
print(u)
print("////////////////////")
print(v)
print("////////////////////")
print(d)
# Out:
# [[-0.59455781  0.80405286]
#  [ 0.80405286  0.59455781]]
# ////////////////////
# [[ 1.  0.]
#  [-0. -1.]]
# ////////////////////
# [1. 1.]

# %%
graficarMatriz(v)
plt.xlim(-1.5,1.5)
plt.ylim(-1.5,1.5)
# Out:
# (-1.5, 1.5)

# %%
mat = np.array([[1, 2],[3, 4],[5, 6]])
penrose = mat.T.dot(mat)
penrose = np.linalg.inv(penrose)
penrose = penrose.dot(mat.T)
print(penrose)
# Out:
# [[-1.33333333 -0.33333333  0.66666667]
#  [ 1.08333333  0.33333333 -0.41666667]]

# %%
x = np.linspace(-5,5,1000)
y1 = 1 * x + 4
y2 = 2 * x + 5
y3 = -3 * x + 6

# %%
matriz = np.array([[1,1],[2,1],[-3,1]])
matriz_pse = np.linalg.pinv(matriz)
print(matriz_pse)
# Out:
# [[ 0.07142857  0.14285714 -0.21428571]
#  [ 0.33333333  0.33333333  0.33333333]]

# %%
b = np.array([[4],[5],[6]])
resultado = matriz_pse.dot(b)
print(resultado)
# Out:
# [[-0.28571429]
#  [ 5.        ]]

# %%
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.scatter(resultado[0],resultado[1])
plt.show()

# %%
mar=np.array([[3, 4], [3, 2]])
autovalores,autovectores=np.linalg.eig(mar)
print( "autovector= ",autovectores)
print( "autovalores= ",autovalores)
# Out:
# autovector=  [[ 0.8        -0.70710678]
#  [ 0.6         0.70710678]]
# autovalores=  [ 6. -1.]
