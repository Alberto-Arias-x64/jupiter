# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np

fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

model = keras.Sequential([keras.layers.Flatten(input_shape = (28, 28)), keras.layers.Dense(128, activation = tf.nn.relu), keras.layers.Dense(10, activation = tf.nn.softmax)])

model.compile(optimizer = tf.optimizers.Adam(), 
              loss = 'sparse_categorical_crossentropy', 
              metrics = ['accuracy'])

model.fit(train_images, train_labels, epochs = 5)

test_loss, test_acc = model.evaluate( test_images, test_labels )

FTpredict=model.predict(test_images)
# Out:
# Wall time: 0 ns
# Epoch 1/5
# 1875/1875 [==============================] - 2s 915us/step - loss: 8.5380 - accuracy: 0.6434
# Epoch 2/5
# 1875/1875 [==============================] - 2s 912us/step - loss: 0.7477 - accuracy: 0.7203
# Epoch 3/5
# 1875/1875 [==============================] - 2s 904us/step - loss: 0.6316 - accuracy: 0.7653
# Epoch 4/5
# 1875/1875 [==============================] - 2s 906us/step - loss: 0.6064 - accuracy: 0.7769
# Epoch 5/5
# 1875/1875 [==============================] - 2s 959us/step - loss: 0.5616 - accuracy: 0.8052
# 313/313 [==============================] - 0s 644us/step - loss: 0.6214 - accuracy: 0.7993
# Wall time: 0 ns

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
plt.imshow(test_images[0],cmap='gray')
plt.xlabel(class_names[train_labels[i]])
# Out:
# Text(0.5, 0, 'Coat')

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(True)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
model = keras.Sequential([keras.layers.Flatten(input_shape=(28,28)),keras.layers.Dense(128,activation = tf.nn.relu),keras.layers.Dense(10,activation = tf.nn.softmax)])

model.compile(optimizer = tf.optimizers.Adam(),loss = 'sparse_categorical_crossentropy',metrics = ['accuracy'])

model.fit(train_images,train_labels,epochs =10)

test_loss, test_acc = model.evaluate(test_images, test_labels)
print('Accuracy ', test_acc)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 11.8330 - accuracy: 0.6650
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6948 - accuracy: 0.7329
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6298 - accuracy: 0.7662
# Epoch 4/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5790 - accuracy: 0.7935
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5609 - accuracy: 0.8028
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5068 - accuracy: 0.8254
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5103 - accuracy: 0.8274
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4892 - accuracy: 0.8343
# Epoch 9/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4771 - accuracy: 0.8359
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4795 - accuracy: 0.8406
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5544 - accuracy: 0.8214
# Accuracy  0.821399986743927

# %%
predictions = model.predict(test_images)
plt.figure(figsize=(10,10))
for i in range(25):
  plt.subplot(5, 5, i + 1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(test_images[i], cmap=plt.cm.binary)
  predicted_label = np.argmax(predictions[i])
  true_label = test_labels[i]
  
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red' 
  etiqueta = class_names[predicted_label] + '(' + class_names[true_label] +')'
  plt.xlabel(etiqueta).set_color(color)
plt.show()
